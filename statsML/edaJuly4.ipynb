# %%
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv("/Users/pawankumarkc/Documents/vscodepython/NLP/Libraries/Practice Datasets/titanic_train.csv")

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Check missing data
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
dataset['Age'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset['Age'].plot(kind='kde')
#KDE = Kernel density estimate
# Out:
# <Axes: ylabel='Density'>

# %%
dataset['Age'].skew()
#positive
# Out:
# 0.38910778230082704

# %%
dataset['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
(dataset['Age'].count()/len(dataset['Age']))*100
#80% of data available, means 20% missing
# Out:
# 80.13468013468014

# %%
dataset['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
dataset['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
dataset['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
dataset['Fare'].skew()
# Out:
# 4.787316519674893

# %%
dataset['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
dataset[dataset['Fare']>100]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %% [markdown]
# # Descriptive analysis

# %% [markdown]
# #Steps of doing univariate analysis on categorical columns

# %%
dataset['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
dataset['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
dataset['Embarked'].value_counts().plot(kind='pie', autopct='%0.1f')
# Out:
# <Axes: ylabel='Embarked'>

# %%
dataset['Embarked'].isnull().sum()
# Out:
# 2

# %%
dataset['Sex'].isnull().sum()
# Out:
# 0

# %%
#Find total missing value and then create new column with missing value percettile

(dataset.isnull().sum()/dataset.shape[0]*100).reset_index().rename(columns={0:'missing_values(%)'})
# Out:
#           index  missing_values(%)
# 0   PassengerId           0.000000
# 1      Survived           0.000000
# 2        Pclass           0.000000
# 3          Name           0.000000
# 4           Sex           0.000000
# 5           Age          19.865320
# 6         SibSp           0.000000
# 7         Parch           0.000000
# 8        Ticket           0.000000
# 9          Fare           0.000000
# 10        Cabin          77.104377
# 11     Embarked           0.224467

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Bivariate analysis
# Means select 2 columns togather
# univariate = 1 column
#
# 1. Select 2 columns
# 2. numer0cal-numerical, num-categorical, cat-cate

# %%
dataset['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
dataset['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sns.heatmap(pd.crosstab(dataset['Survived'], dataset['Pclass'], normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
pd.crosstab(dataset['Survived'], dataset['Pclass'], normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(dataset['Survived'], dataset['Embarked'], normalize='columns')*100)
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
pd.crosstab(dataset['Pclass'], dataset['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
#Survived and age analysis

dataset[dataset['Survived']==1]['Age'].plot(kind='kde', label='Survived')
dataset[dataset['Survived']==0]['Age'].plot(kind='kde', label='Not Survived')
plt.legend()
plt.show()

# %%
dataset['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
dataset['individual_fare']=dataset['Fare']/(dataset[])
# Out:
#   Cell In[40], line 1
#     dataset['individual_fare']=dataset['Fare']/(dataset[])
#                                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#Travel with family
dataset['family_size']= dataset['SibSp'] + dataset['Parch'] +1

# %%
dataset['family_size'].value_counts()
# Out:
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: family_size, dtype: int64

# %%
def transform_family_size(num):
    if num==1:
        return 'alone'
    elif num>1 and num <5:
        return 'small family'
    else:
        return 'large family'

# %%
dataset['family_type'] = dataset['family_size'].apply(transform_family_size)
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  family_size   family_type
# 0      0         A/5 21171   7.2500   NaN        S            2  small family
# 1      0          PC 17599  71.2833   C85        C            2  small family
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1         alone
# ...

# %%
sns.pairplot(dataset, hue="Survived", size=3)
plt.show()

# %%
# Pandas profiling - EDA automation

from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(dataset)
profile.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
