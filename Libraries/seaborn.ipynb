# %% [markdown]
# Date May 15
# # seaborn
# - Seaborn is the extended version of matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt

arr = [1,2,3,4,5,6,7]
arr2 = [2,3,5.5,6,7.8,10,20]

sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': 'black',
#  'axes.grid': False,
#  'axes.axisbelow': 'line',
#  'axes.labelcolor': 'black',
#  'figure.facecolor': 'white',
#  'grid.color': '#b0b0b0',
#  'grid.linestyle': '-',
#  'text.color': 'black',
#  'xtick.color': 'black',
#  'ytick.color': 'black',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.projecting: 'projecting'>,
#  'patch.edgecolor': 'black',
#  'patch.force_edgecolor': False,
#  'image.cmap': 'viridis',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['DejaVu Sans',
#   'Bitstream Vera Sans',
#   'Computer Modern Sans Serif',
#   'Lucida Grande',
#   'Verdana',
#   'Geneva',
#   'Lucid',
#   'Arial',
#   'Helvetica',
#   'Avant Garde',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
# ...

# %%
sns.axes_style('whitegrid', {'figure.facecolor': 'green', 'axes.facecolor': 'blue'} )
plt.plot(arr, arr2)
plt.show()

# %% [markdown]
# # sns.setcontext
#
# Palette options
# - bright
# - muted
# - pastel
# - etc....

# %%
sns.set_theme(style='whitegrid', context='paper', font='monospace', font_scale=1, palette='pastel')

plt.plot(arr, arr2)
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Plot-1')
plt.show()

# %% [markdown]
# #### In seaborn many datasets are available for practise

# %%
#Get list of available datasets
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
ir = sns.load_dataset('iris')

# %% [markdown]
# - Histogram
# - kdeplot
# - boxplot
# - violinplot
# - scatterplot
# - countplot
# - barplot
# - jointplot
# - pairplot
# - regplot
# - Lmplot
# - swarmplot
# - stripplot
# - Heatmap

# %%
## Histogram

# %%
sns.histplot(ir.sepal_length)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
plt.figure(figsize=(8,6))
sns.histplot(x='sepal_length', data=ir, bins=15, kde=True, color='red', stat='frequency')

# stat options = count(default), probability, density
# Out:
# <Axes: xlabel='sepal_length', ylabel='Frequency'>

# %%
sns.displot(data=ir, x='sepal_length', kind='kde')
plt.show()

# %%
sns.displot(data=ir, x='sepal_length', kind='hist', stat='density')
plt.show()

# %% [markdown]
# #### KDE plot

# %%
sns.kdeplot(ir.sepal_length, shade=True)
plt.show()
# Out:
# /var/folders/xf/kbnr5k6x1jdf2_jb1xc41d580000gn/T/ipykernel_1257/2979368223.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ir.sepal_length, shade=True)

# %% [markdown]
# ### Boxplot

# %%
ir.
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.boxplot(data=ir, y='sepal_length', x='species')
plt.show()

# x/y = discrete, hue = categorical

# %% [markdown]
# ### violinplot

# %%
sns.violinplot(data=ir, x='sepal_length')
# Out:
# <Axes: xlabel='sepal_length'>

# %% [markdown]
# ### Scatterplot

# %%
ir.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(data =ir,  x='sepal_length', y='petal_length', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# ### Joint plot
#
# - It returns a multipanel figure

# %%
sns.jointplot(data=ir,x='sepal_length', y='petal_length', hue='species')
plt.show()

# %%
sns.jointplot(data=ir,x='sepal_length', y='petal_length', hue='species', kind='hist')
plt.show()

# %%
sns.jointplot(data=ir,x='sepal_length', y='petal_length', kind='hex')
plt.show()

# %% [markdown]
# ### Pairplot
#
# - It is used to compare one/more columns with other one/more columns

# %%
sns.pairplot(data=ir, x_vars=['sepal_length','sepal_width'], y_vars=['petal_width','petal_width'])

# %%
sns.pairplot(ir, kind='reg', hue='species', diag_kind='hist')

#diag_kind = hist, kde, regression

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(data= ir, x='species', y='sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(data= ir, x='species', y='sepal_length', ci=False)
# Out:
# /var/folders/xf/kbnr5k6x1jdf2_jb1xc41d580000gn/T/ipykernel_1257/2974719112.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data= ir, x='species', y='sepal_length', ci=False)
# <Axes: xlabel='species', ylabel='sepal_length'>
